# %% [markdown]
# # Lab: Interactive Plots with ipywidgets
#
# This Lab will give you some practice with ipywidgets to make interactive plots.
#
# **NOTE: It is *highly* recommended that you hit "Save & Grade" after you answer each prompt in order to catch any errors in order.**

# %% [markdown]
# ## Read in data
#
# Use the `numpy.load` function to load `simdata.npy` with `data = np.load('./simdata.npy')`.
#
# **Make sure you call this variable `data`.**

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
import numpy as np
data = np.load('./simdata.npy')
data
# Out:
# array([[0.02932325, 0.02932325, 0.02932325, ..., 0.38656015, 0.38656015,
#         0.38656015],
#        [0.02932325, 0.02932325, 0.02932325, ..., 0.38656015, 0.38656015,
#         0.38656015],
#        [0.02932325, 0.02932325, 0.02932325, ..., 0.38656015, 0.38656015,
#         0.38656015],
#        ...,
#        [0.38656015, 0.38656015, 0.38656015, ..., 0.38656015, 0.38656015,
#         0.38656015],
#        [0.38656015, 0.38656015, 0.38656015, ..., 0.38656015, 0.38656015,
#         0.38656015],
#        [0.38656015, 0.38656015, 0.38656015, ..., 0.38656015, 0.38656015,
#         0.38656015]])

# %% [markdown]
# ## Building an interactive plot in steps
#
# ### Step 1: Hard-coding a value
#
# Now we will use this data to create a figure with `imshow` where the colormap is "hard coded" as the "jet" colormap (not a great choice!).
#
# Call this figure in the "usual way" with
#
# ```python
# fig_1, ax_1 = plt.subplots()
# ```
#
# And set the colormap's "hard coded" as the parameter `cmap_variable = 'jet'` (see the class notebook for more details).
#
# **Make sure you have checked the naming of your variables ("fig_1", "ax_1", "cmap_variable").**

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
import matplotlib.pyplot as plt
fig_1, ax_1 = plt.subplots()
cmap_variable = 'jet'

ax_1.imshow(data, cmap=cmap_variable)
plt.show()

# %% [markdown]
# ## Step 2: Parameter as function
#
# Now create a function called `create_plot1` that takes the colormap in as a variable.

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
def create_plot1(colormap):
    fig, ax = plt.subplots()
    ax.imshow(data, cmap=colormap)
    plt.show()

# %% [markdown]
# ## Step 2.5: Test out some values
#
# Use your new function to test out some values.

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
create_plot1('jet')   # Should look the same as the previous plot
create_plot1('magma') # Testing a new colormap
create_plot1('Blues') # Another test

# %% [markdown]
# ## Step 3
#
# Using an `@ipywidgets.interact` decorator, add a dropdown menu to select the plot color with the options of ['jet', 'magma', 'Blues'].
#
# Call this new, decorated function `create_plot2`.
#
# **Make sure to call the function `create_plot2` and to use the correct order for your dropdown.**
#
# When finished, you should see a plot with a dropdown that looks like this:
#
# <div>
# <img src="attachment:206fca1d-75c0-4a44-a530-2c4bd276f7cc.png" width="300" />
# </div>

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
import ipywidgets as widgets
from ipywidgets import interact

@interact(cmap_variable=['jet', 'magma', 'Blues'])
def create_plot2(cmap_variable):
    fig, ax = plt.subplots()
    ax.imshow(data, cmap=cmap_variable)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='cmap_variable', options=('jet', 'magma', 'Blues'), value='jet'), O…
