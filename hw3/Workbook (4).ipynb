# %% [markdown]
# # Lab: ipywidgets Linking Workbook
#
# This Lab will give you some practice with linking ipywidgets together to build mini-interfaces.
#
# **NOTE: It is *highly* recommended that you hit "Save & Grade" after you answer each prompt in order to catch any errors in order.**

# %% [markdown]
# ## Question \#1
#
# ### Part 1
#
# Create a [Button](https://ipywidgets.readthedocs.io/en/stable/examples/Widget%20List.html#button) widget with a description of "Click me please!".
#
# **Call this widget "button".**

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
import ipywidgets as widgets
button=widgets.Button(
    value=False,
    description='Click me please!'
    
)
button
# Out:
# Button(description='Click me please!', style=ButtonStyle())

# %% [markdown]
# ## Part 2
#
# Create an "observation" function that will print out the words "Hello world!" whenever `button` is clicked.
#
# Assume you are on a local instance and jupyter notebook, so don't worry about adding an "out" widget or actually linking to your button right now.
#
# **Call this function "observe".**

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
def observe(change):  
        print("Hello world!")

# %% [markdown]
# ### Part 3
#
# Finally, we are going to link your `button` widget with your `observe` function through the `on_click` key of the `button` widget.  In the example prep notebook for local jupyter notebooks, this is done with just a print statement in the `on_click` function as shown by the pseudo-code below:
#
# ```python
# def FUNCTION NAME(...):
#     print(...)
# ```
#
# Because we are practicing in a jupypter lab instance instead of a notebook, we need to do things a little bit differently and capture the "output" of this print statement in our Workbook.ipynb (by default, the print statement in the `on_click` function will actually output to the console -- feel free to give this a shot if you want to see it show up in the console!).
#
# #### Part 3.1
#
# First, create an "output" widget with:
#
# ```python
# out = ipywidgets.Output()
# ```

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
out=widgets.Output()

# %% [markdown]
# #### Part 3.2
#
# Encapsulate your print statement with a `with out:` statement like so:
#
# ```python
# def YOUR FUNCTION(...):
#     ...
#     with out:
#         print(...)
# ```
#
# Note that the above is *pseudocode* and will not run if you try to copy paste -- you need to fill in the ellipses (...) and your function name with the correct code.
#
# **Call this new function "observe2".**
#
# This function should also print out "Hello world!".

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
def observe2(change):
    with out:  
        print("Hello world!")

# %% [markdown]
# ### Part 3.3
#
# Now, link `observe2` to your a user clicking your button with the `.on_click` function (see the class notebooks for more details).

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
button.on_click(observe2)

# %% [markdown]
# ### Part 3.4
#
# Once linking is done, display both `button` and `out` widgets with a vertical box with `button` on top and `out` on the bottom.  **Call this display widget "widget_display".**
#
# **Make sure you test out your widget to see that it prints correctly!**

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
widget_display = widgets.VBox([button, out])
widget_display
